# %% [markdown]
# <a href="https://colab.research.google.com/github/shanthivijayan/Python_Code/blob/main/Pandas_group_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d={'Mouse':[150,200,300,400],
'Keyboard':[180,200,190,300],
'Scanner':[200,280,330,450]}
df=pd.DataFrame(d,index=['Jan','Feb','March','April'])

df
# Out:
#        Mouse  Keyboard  Scanner
# Jan      150       180      200
# Feb      200       200      280
# March    300       190      330
# April    400       300      450

# %% [markdown]
# Write code to access data of Mouse and Scanner columns.

# %%
print(df['Mouse'])
print(df['Scanner'])
print(df[['Mouse','Scanner']])
# Out:
# Jan      150
# Feb      200
# March    300
# April    400
# Name: Mouse, dtype: int64
# Jan      200
# Feb      280
# March    330
# April    450
# Name: Scanner, dtype: int64
#        Mouse  Scanner
# Jan      150      200
# Feb      200      280
# March    300      330
# April    400      450

# %% [markdown]
# Write code to access data of the Keyboard column using dot
# notation and column name.

# %%
print(df.Keyboard)
# Out:
# Jan      180
# Feb      200
# March    190
# April    300
# Name: Keyboard, dtype: int64

# %% [markdown]
# C. Write code to access data of scanners using loc[].

# %%
print(df.loc[:,'Scanner'])
# Out:
# Jan      200
# Feb      280
# March    330
# April    450
# Name: Scanner, dtype: int64

# %% [markdown]
# Write code to access columns using 0 and 2.

# %%
print(df.iloc[:,[0,2]])
# Out:
#        Mouse  Scanner
# Jan      150      200
# Feb      200      280
# March    300      330
# April    400      450

# %% [markdown]
# Write code to access data of all columns where mouse data is
# more than 200.

# %%
df[df["Mouse"]>200]
# Out:
#        Mouse  Keyboard  Scanner
# March    300       190      330
# April    400       300      450

# %% [markdown]
# Write code to access data of rows of jan and march for scanner
# and keyboard

# %%
print(df.iloc[[0,2],[1,2]])
# Out:
#        Keyboard  Scanner
# Jan         180      200
# March       190      330

# %% [markdown]
# 1) Download cities.csv in C7W1 Activity folder
# 2) Import the CSV in a dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as cities1.csv

# %%
dfcity=pd.read_csv('/content/cities.csv')
dfcity
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
dfcity.describe()
# Out:
#              LatD      "LatM"      "LatS"      "LonD"      "LonM"      "LonS"
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean    38.820312   30.765625   27.492188   93.250000   27.742188   26.960938
# std      5.200596   16.426158   18.977814   15.466499   16.927937   18.727807
# min     26.000000    1.000000    0.000000   71.000000    0.000000    0.000000
# 25%     35.000000   16.000000   11.000000   80.000000   14.000000   11.000000
# 50%     39.000000   31.000000   24.000000   89.500000   26.500000   23.500000
# 75%     42.250000   45.000000   47.000000  103.250000   40.250000   47.000000
# max     50.000000   59.000000   59.000000  123.000000   58.000000   59.000000

# %%
import numpy as np
dfcity["New_Column"]="text"
dfcity.columns
dfcity
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State" New_Column
# 0          "Youngstown"       OH       text
# 1             "Yankton"       SD       text
# ...

# %%
dfcity.info()
dfcity["New_Column"].astype(str)
dfcity.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LatD        128 non-null    int64
#  1    "LatM"     128 non-null    int64
#  2    "LatS"     128 non-null    int64
#  3    "NS"       128 non-null    object
#  4    "LonD"     128 non-null    int64
#  5    "LonM"     128 non-null    int64
#  6    "LonS"     128 non-null    int64
#  7    "EW"       128 non-null    object
#  8    "City"     128 non-null    object
#  9    "State"    128 non-null    object
#  10  New_Column  128 non-null    object
# dtypes: int64(6), object(5)
# memory usage: 11.1+ KB
# LatD           int64
#  "LatM"        int64
#  "LatS"        int64
#  "NS"         object
#  "LonD"        int64
#  "LonM"        int64
#  "LonS"        int64
#  "EW"         object
#  "City"       object
#  "State"      object
# New_Column    object
# dtype: object

# %%
dfcity.to_csv("cities1.csv")

# %% [markdown]
# 1) Download CarSalesByModelStart.xlsx in C7W1 Activity folder
# 2) Import xlsx in a dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as CarSalesByModelStart1.xlsx

# %%
dfCar_Sales=pd.read_excel('/content/CarSalesByModelStart.xlsx')
dfCar_Sales
# Out:
#       Year     Month                Date      Model  Dealer ID  Quantity Sold  \
# 0     2018   January 2018-01-01 23:00:00   Beaufort       1222             10
# 1     2018   January 2018-01-01 23:00:00     Salish       1222             13
# 2     2018   January 2018-01-01 23:00:00   Labrador       1222             16
# 3     2018   January 2018-01-01 23:00:00  Champlain       1222              3
# 4     2018   January 2018-01-01 23:00:00     Hudson       1222             22
# ...    ...       ...                 ...        ...        ...            ...
# 1195  2019  December 2019-12-01 23:00:00   Beaufort       1288             12
# 1196  2019  December 2019-12-01 23:00:00     Salish       1288             14
# 1197  2019  December 2019-12-01 23:00:00   Labrador       1288             18
# 1198  2019  December 2019-12-01 23:00:00  Champlain       1288              4
# 1199  2019  December 2019-12-01 23:00:00     Hudson       1288             25
#
#        Profit
# 0     15000.0
# ...

# %%
dfCar_Sales.describe()
# Out:
#               Year    Dealer ID  Quantity Sold        Profit
# count  1200.000000  1200.000000     1200.00000   1200.000000
# mean   2018.500000  1281.800000       17.99750  24974.055208
# std       0.500208    72.453672        9.97432  17370.750612
# min    2018.000000  1212.000000        2.00000   4600.000000
# 25%    2018.000000  1217.000000       11.00000  13500.000000
# 50%    2018.500000  1256.000000       18.00000  18500.000000
# 75%    2019.000000  1336.000000       24.00000  28922.812500
# max    2019.000000  1402.000000       48.00000  83875.000000

# %%
dfCar_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          1200 non-null   object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 65.8+ KB

# %%
dfCar_Sales.to_excel('CarSalesByModelStart1.xlsx')

# %% [markdown]
# ) Download Jay.json in C7W1 Activity folder
# 2) Import the Json in dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as Jay1.json

# %%
dfjay=pd.read_json('/content/Jay (1).json')
dfjay
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
dfjay.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.800000
# std     42.299949   14.510259   16.450434   266.377134
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
dfjay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB

# %%
dfjay.to_json('Jay1.json')

# %% [markdown]
# 1. Find how many records this data frame has;
# 2. How many elements are there?
# 3. What are the column names?
# 4. What types of columns do we have in this data frame?
# 5. Give the summary for the numeric columns in the dataset
# 6. Calculate standard deviation for all numeric columns;
# 7. What are the mean values of the first 50 records in the dataset? Hint:
# use head() method to subset the first 50 records and then calculate the
# mean

# %%
path='/content/GoodBelly-DataSet.xlsx'
#dfGoodBelly=pd.read_excel('/content/GoodBelly-DataSet-Regression.xlsx')
#path="C://Users//shant//Downloads//GoodBelly-DataSet.xlsx"
#dfGoodBelly=pd.read_excel(path)

dfGoodBelly = pd.read_excel(path, sheet_name='Real Data')
dfGoodBelly
# Out:
#            Date Region                    Store  Units Sold  \
# 0    2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1    2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2    2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3    2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4    2010-06-01     FL  Biscayne (aka Aventura)  257.688151
# ...         ...    ...                      ...         ...
# 1381 2010-06-15     SW                 Veterans  192.685157
# 1382 2010-06-22     SW                 Veterans  173.720882
# 1383 2010-06-29     SW                 Veterans  278.582872
# 1384 2010-07-06     SW                 Veterans  122.229768
# 1385 2010-07-13     SW                 Veterans  166.893026
#
#       Average Retail Price  Sales Rep  Endcap  Demo  Demo1-3  Demo4-5  \
# 0                 4.390000          0       0     0        0        0
# 1                 3.997692          0       0     0        0        0
# ...

# %%
#How many elements are there?
dfGoodBelly.size
# Out:
# 16632

# %%
dfGoodBelly.shape
# Out:
# (1386, 12)

# %%
#How many records in Dataframe
len(dfGoodBelly)
# Out:
# 1386

# %%
#What are the column names?
dfGoodBelly.columns
# Out:
# Index(['Date', 'Region', 'Store', 'Units Sold', 'Average Retail Price',
#        'Sales Rep', 'Endcap', 'Demo', 'Demo1-3', 'Demo4-5', 'Natural',
#        'Fitness'],
#       dtype='object')

# %%
#What types of columns do we have in this data frame?
dfGoodBelly.dtypes
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object

# %%
#Give the summary for the numeric columns in the dataset
dfnumeric=dfGoodBelly._get_numeric_data()
dfnumeric.describe()
# Out:
#         Units Sold  Average Retail Price    Sales Rep       Endcap  \
# count  1386.000000           1386.000000  1386.000000  1386.000000
# mean    253.820718              4.107093     0.549784     0.038240
# std     110.998731              0.463828     0.497695     0.191843
# min      47.559852              2.889286     0.000000     0.000000
# 25%     189.995471              3.775714     0.000000     0.000000
# 50%     236.735266              4.096667     1.000000     0.000000
# 75%     295.804391              4.425067     1.000000     0.000000
# max    1041.200256              6.251538     1.000000     1.000000
#
#               Demo      Demo1-3      Demo4-5      Natural      Fitness
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.058442     0.156566     0.075758     1.448773     2.476190
# std       0.234661     0.363522     0.264705     0.975092     1.592789
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
dfnumeric.std()
# Out:
# Units Sold              110.998731
# Average Retail Price      0.463828
# Sales Rep                 0.497695
# Endcap                    0.191843
# Demo                      0.234661
# Demo1-3                   0.363522
# Demo4-5                   0.264705
# Natural                   0.975092
# Fitness                   1.592789
# dtype: float64

# %%
#What are the mean values of the first 50 records in the dataset? Hint: use head() method to subset the first 50 records and then calculate the mean
#dfmean=dfGoodBelly.head(50)
dfmean=dfnumeric.head(50)
dfmean.mean()
# Out:
# Units Sold              186.280727
# Average Retail Price      4.128036
# Sales Rep                 0.000000
# Endcap                    0.100000
# Demo                      0.000000
# Demo1-3                   0.000000
# Demo4-5                   0.040000
# Natural                   1.300000
# Fitness                   1.560000
# dtype: float64
